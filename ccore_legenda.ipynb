# %% [markdown]
# # Lengendando qualquer filme em qualquer lingua de forma simples
#
#
# Instale as libraries

# %%
# !pip install --upgrade youtube-dl
# !git clone https://github.com/agermanidis/autosub.git
# !pip install googletrans

# %%
cd ./autosub

# %%
# !python setup.py install

# %%
cd /content/
# Out:
# /content

# %% [markdown]
# # Traduzindo video do youtube - Quando ja possui "tradução automatica"
# 1- baixar video(só faça isso com videos sem direitos autorais) :)
#
#
# O comando é:
# a)Quando ja possui tradução automatica:
#
#
# ` !youtube-dl (link) --write-auto-sub  --sub-lang (lingua) --convert-subs srt --format mp4 -o video.mp4`
#
#
# b)Quando não possui tradução automatica:
#
#
# ` !youtube-dl (link) --format mp4 -o video.mp4`

# %%
# !youtube-dl https://www.youtube.com/watch?v=fwrx8wrJNqk --write-auto-sub  --sub-lang en --convert-subs srt --format mp4 -o video.mp4
# Out:
# [youtube] fwrx8wrJNqk: Downloading webpage
# [youtube] fwrx8wrJNqk: Looking for automatic captions
# [info] Writing video subtitles to: video.en.vtt
# [download] Destination: video.mp4
# [download] 100% of 28.09MiB in 00:01
# [ffmpeg] Converting subtitles
# Deleting original file video.en.vtt (pass -k to keep)

# %% [markdown]
# # Caso não possua legenda automatica
# vai usar o comando autosub, que irá extrair a legenda na lingua nativa,
#
# então você precisa rodar o comando:
#
#
# `!autosub video.mp4 -S pt -D pt` (no caso para extrair a legenda se o video for em portugues)
#
#
# `!autosub video.mp4 -S en -D en ` (no caso para extrair a legenda se o video for em ingles)

# %% [markdown]
# **Criando legenda**

# %%
# !autosub video.mp4 -S pt -D pt
# Out:
# Converting speech regions to FLAC files: 100% || Time: 0:00:09
# Performing speech recognition: 100% || Time: 0:00:18
# Subtitles file created at video.srt

# %% [markdown]
# **Traduzindo a legenda**

# %%
from googletrans import Translator
f = open("video.srt", "r")
fulltext=''
c=0
temp=''
t=f.readline()
translator = Translator()
t=translator.translate(t)
for x in f:
  c=c+1
  temp=temp+x
  if c>20:
    c=0
    l=translator.translate(temp)
    fulltext=fulltext+l.text
    temp=''
l=translator.translate(temp)
fulltext=fulltext+l.text
fulltext=fulltext.replace(": ", ":").replace("->", "-->")    
s = open("video2.srt", "w")
s.write(fulltext)
s.close()

# %% [markdown]
# **Adicionando Lengenda ao Video**
# usando o ffmpeg com aceleracao de hardware
#
# ---
#
#
#
#
# codigo:
#
#
#
# ```
# ffmpeg -i VIDEO.mp4  -vcodec nvenc       -vf "subtitles=LEGENDA.srt:force_style='Fontsize=22,Fontname=Ubuntu Bold,PrimaryColour=&Hffffff,SecondaryColour=&Hffffff,OutlineColour=&H44000000,BackColour=&H0,BorderStyle=3,Shadow=0'" FINAL.mp4
# ```

# %%
# !ffmpeg -i video.mp4         -vf "subtitles=/content/video2.srt:force_style='Fontsize=22,Fontname=Ubuntu Bold,PrimaryColour=&Hffffff,SecondaryColour=&Hffffff,OutlineColour=&H44000000,BackColour=&H0,BorderStyle=3,Shadow=0'" final.mp4
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !ffmpeg -codecs
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %% [markdown]
# **Cortando videos**
# comando:
#
# ```
# !ffmpeg -vcodec nvenc -i final.mp4 -t (TEMPO DO VIDEO) -ss (segundo de inicio) final_cortado.mp4
# ```

# %%
# !ffmpeg -vcodec nvenc -i final.mp4 -t 140 -s 10 final_cortado.mp4
